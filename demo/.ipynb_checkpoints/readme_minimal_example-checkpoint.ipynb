# %%
# Minimal example
import remeta
stimuli, choices, confidence = remeta.load_dataset('simple')
cfg = remeta.Configuration()
rem = remeta.ReMeta(cfg=cfg)
rem.fit(stimuli, choices, confidence)
# Out:
# Loading dataset 'simple' which was generated with the following parameters:
#     [true] noise_sens: 0.4
#     [true] bias_sens: 0.2
#     [true] noise_meta: 0.4
#     [true] evidence_bias_mult_meta: 1.2
#     [true] evidence_bias_add_meta: 0.1
# No. subjects: 1, No. samples: 1000
# Metatacognitive noise type: noisy_report
# Metatacognitive noise distribution: truncated_norm
# Link function: probability_correct
#
# +++ Sensory level +++
# Initial neg. LL: 782.63
#     [initial] noise_sens: 0.1
#     [initial] bias_sens: 0
# Performing local optimization
#     [final] noise_sens: 0.388
#     [final] bias_sens: 0.201
# Final stats: 0.19 secs, 117 fevs
# Final neg. LL: 267.18
#
# +++ Metacognitive level +++
# Initial neg. LL: 1913.83
#     [initial] noise_meta: 0.2
#     [initial] evidence_bias_mult_meta: 1
#     [initial] evidence_bias_add_meta: 0
# Grid search activated (grid size = 300)
#     [grid] noise_meta: 0.35
#     [grid] evidence_bias_mult_meta: 0.5
#     [grid] evidence_bias_add_meta: 0.2
# Grid neg. LL: 1774.3
# Grid runtime: 10.34 secs
# Performing local optimization
#     [final] noise_meta: 0.329
#     [final] evidence_bias_mult_meta: 0.303
#     [final] evidence_bias_add_meta: 0.251
# Final stats: 2.24 secs, 61 fevs
# Final neg. LL: 1772.94
